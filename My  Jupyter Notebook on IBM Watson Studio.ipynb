# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Valentina Mesa Sotelo
# Data Scientist**

# %% [markdown]
# *Im interested in data science because it has become a demanding skils*

# %% [markdown]
# The following code must dispplay and output

# %%
5*4-98
# Out:
# -78

# %% [markdown]
# ***thanks for scoring my assesment***

# %% [markdown]
#  * Are you having fun

# %% [markdown]
#  * How are you?

# %% [markdown]
#  * Do you like Data Science?

# %% [markdown]
# __https://www.coursera.org/__

# %% [markdown]
# ![catttss.jpeg](attachment:catttss.jpeg)
